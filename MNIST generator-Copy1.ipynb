# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch import nn, Tensor
from torchvision import datasets
from torch.utils.data import DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torchvision.transforms as transforms
from torch.utils.data import Subset

# %%
from torchvision import datasets, transforms
import torch

batch_size = 64
target_class = 1  # Choisis la classe de CIFAR-10 (0 à 9)

# Transformation : conversion en tensor + normalisation
transform = transforms.Compose([
    transforms.ToTensor(),
])

# Téléchargement du dataset CIFAR-10
cifar10_train = datasets.CIFAR10(root="./data", train=True, download=True, transform=transform)

# Filtrage pour ne garder qu'une seule classe
indices = [i for i, label in enumerate(cifar10_train.targets) if label == target_class]
cifar10_single_class = Subset(cifar10_train, indices)

# DataLoader
train_loader = torch.utils.data.DataLoader(cifar10_single_class, batch_size=batch_size, shuffle=True)

print(f"Nombre d'images dans la classe {target_class}: {len(cifar10_single_class)}")
# Out:
# Files already downloaded and verified
# Nombre d'images dans la classe 1: 5000

# %%
len(indices)
# Out:
# 5000

# %%
img, label = cifar10_single_class[np.random.randint(0,5000)]  # récupère l'image et le label
img = img.permute(1, 2, 0)  # passe de (C,H,W) à (H,W,C)

plt.imshow(img)
plt.axis('off')
plt.show()

print("Label :", label)
print("Shape de l'image :", img.shape)
# Out:
# Label : 1
# Shape de l'image : torch.Size([32, 32, 3])

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import CNN1 as CNN1
model = CNN1.CNN1()

# %%
n_epochs = 10000

optim = torch.optim.Adam(model.parameters(), lr=0.0001) 
scheduler = ReduceLROnPlateau(optim, mode='min', factor=0.5, patience=50, verbose=True)
model = model.to(device)

for epoch in range(n_epochs):

    x_1, _ = next(iter(train_loader)) 
    x_1 = x_1.to(device).to(torch.float32)

    x_0 = torch.randn_like(x_1).to(device)

    t = torch.rand(batch_size, 1).to(device)

    x_t = (1 - t.view(-1, 1, 1, 1)) * x_0 + t.view(-1, 1, 1, 1) * x_1

    v_true = x_1 - x_0  

    v_pred = model(x_t, t)

    loss = ((v_pred - v_true) ** 2).mean()

    optim.zero_grad()
    loss.backward()
    optim.step()

    if epoch % 100 == 0:
        print(f"epoch {epoch} | loss = {loss.item():.4f}")
# Out:
# /opt/campux/virtualenv/deeplearning-u24/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# epoch 0 | loss = 1.1179
# epoch 100 | loss = 0.4351
# epoch 200 | loss = 0.3271
# epoch 300 | loss = 0.3044
# epoch 400 | loss = 0.2805
# epoch 500 | loss = 0.2320
# epoch 600 | loss = 0.2175
# epoch 700 | loss = 0.2444
# epoch 800 | loss = 0.2516
# epoch 900 | loss = 0.2342
# epoch 1000 | loss = 0.2038
# epoch 1100 | loss = 0.1758
# epoch 1200 | loss = 0.1734
# epoch 1300 | loss = 0.1732
# epoch 1400 | loss = 0.2375
# epoch 1500 | loss = 0.2102
# epoch 1600 | loss = 0.1952
# epoch 1700 | loss = 0.1961
# epoch 1800 | loss = 0.1851
# epoch 1900 | loss = 0.1724
# epoch 2000 | loss = 0.1679
# epoch 2100 | loss = 0.1706
# epoch 2200 | loss = 0.1832
# epoch 2300 | loss = 0.1611
# epoch 2400 | loss = 0.1691
# epoch 2500 | loss = 0.1651
# epoch 2600 | loss = 0.1664
# epoch 2700 | loss = 0.1480
# epoch 2800 | loss = 0.1641
# epoch 2900 | loss = 0.1541
# epoch 3000 | loss = 0.1676
# epoch 3100 | loss = 0.1611
# epoch 3200 | loss = 0.1589
# epoch 3300 | loss = 0.1663
# epoch 3400 | loss = 0.1589
# epoch 3500 | loss = 0.2028
# epoch 3600 | loss = 0.1545
# epoch 3700 | loss = 0.1457
# epoch 3800 | loss = 0.1699
# epoch 3900 | loss = 0.1434
# epoch 4000 | loss = 0.1488
# epoch 4100 | loss = 0.1623
# epoch 4200 | loss = 0.1347
# epoch 4300 | loss = 0.1496
# epoch 4400 | loss = 0.1762
# epoch 4500 | loss = 0.1460
# epoch 4600 | loss = 0.1464
# epoch 4700 | loss = 0.1439
# epoch 4800 | loss = 0.1621
# epoch 4900 | loss = 0.1362
# epoch 5000 | loss = 0.1486
# epoch 5100 | loss = 0.1550
# epoch 5200 | loss = 0.1529
# epoch 5300 | loss = 0.1532
# epoch 5400 | loss = 0.1418
# epoch 5500 | loss = 0.1590
# epoch 5600 | loss = 0.1475
# epoch 5700 | loss = 0.1581
# epoch 5800 | loss = 0.1523
# epoch 5900 | loss = 0.1398
# epoch 6000 | loss = 0.1551
# epoch 6100 | loss = 0.1347
# epoch 6200 | loss = 0.1518
# epoch 6300 | loss = 0.1393
# epoch 6400 | loss = 0.1634
# epoch 6500 | loss = 0.1301
# epoch 6600 | loss = 0.1444
# epoch 6700 | loss = 0.1514
# epoch 6800 | loss = 0.1462
# epoch 6900 | loss = 0.1426
# epoch 7000 | loss = 0.1463
# epoch 7100 | loss = 0.1398
# epoch 7200 | loss = 0.1504
# epoch 7300 | loss = 0.1434
# epoch 7400 | loss = 0.1457
# epoch 7500 | loss = 0.1405
# epoch 7600 | loss = 0.1530
# epoch 7700 | loss = 0.1575
# epoch 7800 | loss = 0.1467
# epoch 7900 | loss = 0.1388
# epoch 8000 | loss = 0.1675
# epoch 8100 | loss = 0.1332
# epoch 8200 | loss = 0.1489
# epoch 8300 | loss = 0.1481
# epoch 8400 | loss = 0.1522
# epoch 8500 | loss = 0.1444
# epoch 8600 | loss = 0.1439
# epoch 8700 | loss = 0.1408
# epoch 8800 | loss = 0.1388
# epoch 8900 | loss = 0.1443
# epoch 9000 | loss = 0.1569
# epoch 9100 | loss = 0.1396
# epoch 9200 | loss = 0.1415
# epoch 9300 | loss = 0.1466
# epoch 9400 | loss = 0.1510
# epoch 9500 | loss = 0.1627
# epoch 9600 | loss = 0.1353
# epoch 9700 | loss = 0.1506
# epoch 9800 | loss = 0.1325
# epoch 9900 | loss = 0.1496

# %%
import torch

def generate_image(model, steps=100, device="cuda"):

    x_t = torch.randn(1, 1, 28, 28, device=device)

    dt = 1.0 / steps
    
    for step in range(steps):
        t = torch.tensor([[1.0 - step*dt]], device=device)  # t décroissant de 1 à 0
        v = model(x_t, t)
        x_t = x_t + dt * v  
    
    x_gen = torch.clip(x_t, 0.0, 1.0)
    return x_gen

# %%
def generate_imageRGB(model, steps=100, device="cuda"):
    # Bruit initial : 3 canaux, taille 32x32
    x_t = torch.randn(1, 3, 32, 32, device=device)

    dt = 1.0 / steps
    
    for step in range(steps):
        # t décroissant de 1 à 0
        t = torch.tensor([[1.0 - step*dt]], device=device)  # taille (1,1)
        v = model(x_t, t)
        x_t = x_t + dt * v  
    
    # Clamp pour rester dans [0,1]
    x_gen = torch.clamp(x_t, 0.0, 1.0)
    return x_gen

# %%
model = model.to(device)
x_gen = generate_image(model)
import matplotlib.pyplot as plt
plt.imshow(x_gen[0,0].cpu().detach(), cmap="gray")
plt.axis("off")
plt.show()

# %%
import UNET as UNET


model2 = UNET.UNet4()

# %%
n_epochs = 5000
model2 = model2.to(device)

optim = torch.optim.Adam(model2.parameters(), lr=0.0001) 
scheduler = ReduceLROnPlateau(optim, mode='min', factor=0.5, patience=50, verbose=True)


for epoch in range(n_epochs):

    x_1, _ = next(iter(train_loader)) 
    x_1 = x_1.to(device).to(torch.float32)

    x_0 = torch.randn_like(x_1).to(device)

    t = torch.rand(batch_size, 1).to(device)

    x_t = (1 - t.view(-1, 1, 1, 1)) * x_0 + t.view(-1, 1, 1, 1) * x_1

    v_true = x_1 - x_0  

    v_pred = model2(x_t, t)

    loss = ((v_pred - v_true) ** 2).mean()

    optim.zero_grad()
    loss.backward()
    optim.step()

    if epoch % 200 == 0:
        print(f"epoch {epoch} | loss = {loss.item():.4f}")
# Out:
# epoch 0 | loss = 1.0976
# epoch 200 | loss = 0.3791
# epoch 400 | loss = 0.2850
# epoch 600 | loss = 0.2322
# epoch 800 | loss = 0.2351
# epoch 1000 | loss = 0.2660
# epoch 1200 | loss = 0.1789
# epoch 1400 | loss = 0.1842
# epoch 1600 | loss = 0.1731
# epoch 1800 | loss = 0.1778
# epoch 2000 | loss = 0.1323
# epoch 2200 | loss = 0.1713
# epoch 2400 | loss = 0.1860
# epoch 2600 | loss = 0.1693
# epoch 2800 | loss = 0.1402
# epoch 3000 | loss = 0.1472
# epoch 3200 | loss = 0.1771
# epoch 3400 | loss = 0.1441
# epoch 3600 | loss = 0.1261
# epoch 3800 | loss = 0.1495
# epoch 4000 | loss = 0.1260
# epoch 4200 | loss = 0.1454
# epoch 4400 | loss = 0.1436
# epoch 4600 | loss = 0.1215
# epoch 4800 | loss = 0.1211

# %%
x_gen = generate_image(model2)
import matplotlib.pyplot as plt
plt.imshow(x_gen[0,0].cpu().detach(), cmap="gray")
plt.axis("off")
plt.show()

# %%
import UNET2CIFAR as UNET2c


model3 = UNET2c.UNetEnhancedCIFAR()

# %%
n_epochs = 2000
model3 = model3.to(device)

optim = torch.optim.Adam(model3.parameters(), lr=0.001) 

for epoch in range(n_epochs):

    x_1, _ = next(iter(train_loader)) 
    x_1 = x_1.to(device).to(torch.float32)

    x_0 = torch.randn_like(x_1).to(device)

    t = torch.rand(batch_size, 1).to(device)

    x_t = (1 - t.view(-1, 1, 1, 1)) * x_0 + t.view(-1, 1, 1, 1) * x_1

    v_true = x_1 - x_0  

    v_pred = model3(x_t, t)

    loss = ((v_pred - v_true) ** 2).mean()

    optim.zero_grad()
    loss.backward()
    optim.step()

    if epoch % 100 == 0:
        print(f"epoch {epoch} | loss = {loss.item():.4f}")
# Out:
# epoch 0 | loss = 1.3827
# epoch 100 | loss = 0.1560
# epoch 200 | loss = 0.1607
# epoch 300 | loss = 0.2059
# epoch 400 | loss = 0.1267
# epoch 500 | loss = 0.1550
# epoch 600 | loss = 0.1300
# epoch 700 | loss = 0.1232
# epoch 800 | loss = 0.1397
# epoch 900 | loss = 0.1417
# epoch 1000 | loss = 0.1178
# epoch 1100 | loss = 0.1117
# epoch 1200 | loss = 0.1169
# epoch 1300 | loss = 0.1294
# epoch 1400 | loss = 0.1107
# epoch 1500 | loss = 0.1147
# epoch 1600 | loss = 0.0952
# epoch 1700 | loss = 0.1313
# epoch 1800 | loss = 0.1377
# epoch 1900 | loss = 0.0953

# %%
x_gen = generate_imageRGB(model3)
img = x_gen[0].permute(1, 2, 0).cpu().detach()  # (H, W, C)

plt.imshow(img)
plt.axis("off")
plt.show()

# %%
x_gen = generate_image(model3)
import matplotlib.pyplot as plt
plt.imshow(x_gen[0,0].cpu().detach(), cmap="gray")
plt.axis("off")
plt.show()
